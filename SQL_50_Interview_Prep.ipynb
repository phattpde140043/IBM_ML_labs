# %% [markdown]
# # 50 bài SQL luyện interview từ cơ bản → Middle/Advanced
# Notebook này được thiết kế dựa trên kiến trúc của bài test Python trước đó.
# Mỗi bài tập sẽ có một hàm chứa chuỗi `query`. Bạn cần điền câu SQL của mình vào đó. Hàm `test_xx()` sẽ chạy query qua Pandas và hiển thị kết quả.

# %%
import sqlite3
import pandas as pd
from IPython.display import display

# Tạo in-memory database
conn = sqlite3.connect(':memory:')
cursor = conn.cursor()

# Tạo bảng users
cursor.execute('''
CREATE TABLE users (
    user_id INTEGER PRIMARY KEY,
    name TEXT,
    age INTEGER,
    email TEXT,
    country TEXT,
    salary REAL,
    department_id INTEGER
)
''')

# Tạo bảng orders
cursor.execute('''
CREATE TABLE orders (
    order_id INTEGER PRIMARY KEY,
    user_id INTEGER,
    amount REAL,
    order_date DATE
)
''')

# Tạo bảng departments
cursor.execute('''
CREATE TABLE departments (
    department_id INTEGER PRIMARY KEY,
    department_name TEXT
)
''')

# Tạo bảng employees (cho bài self-join)
cursor.execute('''
CREATE TABLE employees (
    employee_id INTEGER PRIMARY KEY,
    name TEXT,
    salary REAL,
    department_id INTEGER,
    manager_id INTEGER
)
''')

# Insert Mock Data
cursor.executescript('''
INSERT INTO departments VALUES (1, 'IT'), (2, 'HR'), (3, 'Sales'), (4, 'Marketing');

INSERT INTO users VALUES 
(1, 'Alice', 25, 'alice@gmail.com', 'USA', 6000, 1),
(2, 'Bob', 30, 'bob@yahoo.com', 'UK', 4500, 2),
(3, 'Charlie', 22, 'charlie@gmail.com', 'USA', 7000, 1),
(4, 'David', 35, 'david@hotmail.com', 'Canada', 3000, 3),
(5, 'Eve', 28, 'eve@gmail.com', 'UK', 5500, 1),
(6, 'Frank', 40, 'frank@company.com', 'Australia', 8000, 3),
(7, 'Grace', 27, 'grace@gmail.com', 'Canada', 4800, 2),
(8, 'Alice', 29, 'alice.duplicate@gmail.com', 'USA', 5200, 4);

INSERT INTO orders VALUES
(101, 1, 250.0, '2023-01-15'),
(102, 1, 150.0, '2023-02-20'),
(103, 2, 500.0, '2023-01-18'),
(104, 3, 1000.0, '2023-03-05'),
(105, 5, 300.0, '2023-02-10'),
(106, 6, 800.0, '2023-04-12');

INSERT INTO employees VALUES
(1, 'Big Boss', 10000, 1, NULL),
(2, 'Manager A', 8000, 1, 1),
(3, 'Employee 1', 5000, 1, 2),
(4, 'Employee 2', 6000, 1, 2),
(5, 'Manager B', 7500, 2, 1),
(6, 'Employee 3', 4000, 2, 5);
''')
conn.commit()

print("Database and Mock Data initialized successfully!")

# %%
# 1. Lấy tất cả user theo tuổi giảm dần
# Mô tả: Viết câu query lấy tất cả user, sắp xếp theo age giảm dần.

def get_result_1(conn):
    # TODO: Viết câu query của bạn vào đây
    query = """
    SELECT 1; -- Thay bằng query của bạn
    """
    return pd.read_sql_query(query, conn)

def test_1(conn):
    try:
        df = get_result_1(conn)
        print("Query executed successfully. Result shape:", df.shape)
        display(df.head()) # Hiển thị 5 dòng đầu
        # Nếu muốn test chặt chẽ, có thể thêm các câu lệnh assert ở đây (ví dụ: assert len(df) > 0)
    except Exception as e:
        print("Error executing query:", e)

# test_1(conn) # Uncomment dòng này để chạy test sau khi viết xong query

# %%
# 2. Tìm user có salary > 5000
# Mô tả: Lấy thông tin các user có salary lớn hơn 5000.

def get_result_2(conn):
    # TODO: Viết câu query của bạn vào đây
    query = """
    SELECT 1; -- Thay bằng query của bạn
    """
    return pd.read_sql_query(query, conn)

def test_2(conn):
    try:
        df = get_result_2(conn)
        print("Query executed successfully. Result shape:", df.shape)
        display(df.head()) # Hiển thị 5 dòng đầu
        # Nếu muốn test chặt chẽ, có thể thêm các câu lệnh assert ở đây (ví dụ: assert len(df) > 0)
    except Exception as e:
        print("Error executing query:", e)

# test_2(conn) # Uncomment dòng này để chạy test sau khi viết xong query

# %%
# 3. Lọc theo nhiều điều kiện AND/OR
# Mô tả: Lấy các user ở USA và có salary > 5000 hoặc user ở UK.

def get_result_3(conn):
    # TODO: Viết câu query của bạn vào đây
    query = """
    SELECT 1; -- Thay bằng query của bạn
    """
    return pd.read_sql_query(query, conn)

def test_3(conn):
    try:
        df = get_result_3(conn)
        print("Query executed successfully. Result shape:", df.shape)
        display(df.head()) # Hiển thị 5 dòng đầu
        # Nếu muốn test chặt chẽ, có thể thêm các câu lệnh assert ở đây (ví dụ: assert len(df) > 0)
    except Exception as e:
        print("Error executing query:", e)

# test_3(conn) # Uncomment dòng này để chạy test sau khi viết xong query

# %%
# 4. Tìm user name bắt đầu bằng 'A'
# Mô tả: Lọc các user có name bắt đầu bằng chữ A.

def get_result_4(conn):
    # TODO: Viết câu query của bạn vào đây
    query = """
    SELECT 1; -- Thay bằng query của bạn
    """
    return pd.read_sql_query(query, conn)

def test_4(conn):
    try:
        df = get_result_4(conn)
        print("Query executed successfully. Result shape:", df.shape)
        display(df.head()) # Hiển thị 5 dòng đầu
        # Nếu muốn test chặt chẽ, có thể thêm các câu lệnh assert ở đây (ví dụ: assert len(df) > 0)
    except Exception as e:
        print("Error executing query:", e)

# test_4(conn) # Uncomment dòng này để chạy test sau khi viết xong query

# %%
# 5. Tìm email chứa domain gmail
# Mô tả: Lọc các user có email dùng gmail.com.

def get_result_5(conn):
    # TODO: Viết câu query của bạn vào đây
    query = """
    SELECT 1; -- Thay bằng query của bạn
    """
    return pd.read_sql_query(query, conn)

def test_5(conn):
    try:
        df = get_result_5(conn)
        print("Query executed successfully. Result shape:", df.shape)
        display(df.head()) # Hiển thị 5 dòng đầu
        # Nếu muốn test chặt chẽ, có thể thêm các câu lệnh assert ở đây (ví dụ: assert len(df) > 0)
    except Exception as e:
        print("Error executing query:", e)

# test_5(conn) # Uncomment dòng này để chạy test sau khi viết xong query

# %%
# 6. DISTINCT country
# Mô tả: Lấy danh sách các quốc gia (không trùng lặp) từ bảng users.

def get_result_6(conn):
    # TODO: Viết câu query của bạn vào đây
    query = """
    SELECT 1; -- Thay bằng query của bạn
    """
    return pd.read_sql_query(query, conn)

def test_6(conn):
    try:
        df = get_result_6(conn)
        print("Query executed successfully. Result shape:", df.shape)
        display(df.head()) # Hiển thị 5 dòng đầu
        # Nếu muốn test chặt chẽ, có thể thêm các câu lệnh assert ở đây (ví dụ: assert len(df) > 0)
    except Exception as e:
        print("Error executing query:", e)

# test_6(conn) # Uncomment dòng này để chạy test sau khi viết xong query

# %%
# 7. LIMIT/TOP/FETCH FIRST
# Mô tả: Lấy 3 user có salary cao nhất.

def get_result_7(conn):
    # TODO: Viết câu query của bạn vào đây
    query = """
    SELECT 1; -- Thay bằng query của bạn
    """
    return pd.read_sql_query(query, conn)

def test_7(conn):
    try:
        df = get_result_7(conn)
        print("Query executed successfully. Result shape:", df.shape)
        display(df.head()) # Hiển thị 5 dòng đầu
        # Nếu muốn test chặt chẽ, có thể thêm các câu lệnh assert ở đây (ví dụ: assert len(df) > 0)
    except Exception as e:
        print("Error executing query:", e)

# test_7(conn) # Uncomment dòng này để chạy test sau khi viết xong query

# %%
# 8. CASE WHEN classify salary level
# Mô tả: Phân loại salary: >6000 là 'High', 4000-6000 là 'Medium', còn lại là 'Low'.

def get_result_8(conn):
    # TODO: Viết câu query của bạn vào đây
    query = """
    SELECT 1; -- Thay bằng query của bạn
    """
    return pd.read_sql_query(query, conn)

def test_8(conn):
    try:
        df = get_result_8(conn)
        print("Query executed successfully. Result shape:", df.shape)
        display(df.head()) # Hiển thị 5 dòng đầu
        # Nếu muốn test chặt chẽ, có thể thêm các câu lệnh assert ở đây (ví dụ: assert len(df) > 0)
    except Exception as e:
        print("Error executing query:", e)

# test_8(conn) # Uncomment dòng này để chạy test sau khi viết xong query

# %%
# 9. COALESCE xử lý NULL
# Mô tả: Giả sử bảng employees có manager_id có thể NULL, dùng COALESCE để hiển thị 'No Manager'.

def get_result_9(conn):
    # TODO: Viết câu query của bạn vào đây
    query = """
    SELECT 1; -- Thay bằng query của bạn
    """
    return pd.read_sql_query(query, conn)

def test_9(conn):
    try:
        df = get_result_9(conn)
        print("Query executed successfully. Result shape:", df.shape)
        display(df.head()) # Hiển thị 5 dòng đầu
        # Nếu muốn test chặt chẽ, có thể thêm các câu lệnh assert ở đây (ví dụ: assert len(df) > 0)
    except Exception as e:
        print("Error executing query:", e)

# test_9(conn) # Uncomment dòng này để chạy test sau khi viết xong query

# %%
# 10. BETWEEN date range
# Mô tả: Tìm các order được tạo trong tháng 1 năm 2023.

def get_result_10(conn):
    # TODO: Viết câu query của bạn vào đây
    query = """
    SELECT 1; -- Thay bằng query của bạn
    """
    return pd.read_sql_query(query, conn)

def test_10(conn):
    try:
        df = get_result_10(conn)
        print("Query executed successfully. Result shape:", df.shape)
        display(df.head()) # Hiển thị 5 dòng đầu
        # Nếu muốn test chặt chẽ, có thể thêm các câu lệnh assert ở đây (ví dụ: assert len(df) > 0)
    except Exception as e:
        print("Error executing query:", e)

# test_10(conn) # Uncomment dòng này để chạy test sau khi viết xong query

# %%
# 11. COUNT tổng số user
# Mô tả: Đếm tổng số lượng user.

def get_result_11(conn):
    # TODO: Viết câu query của bạn vào đây
    query = """
    SELECT 1; -- Thay bằng query của bạn
    """
    return pd.read_sql_query(query, conn)

def test_11(conn):
    try:
        df = get_result_11(conn)
        print("Query executed successfully. Result shape:", df.shape)
        display(df.head()) # Hiển thị 5 dòng đầu
        # Nếu muốn test chặt chẽ, có thể thêm các câu lệnh assert ở đây (ví dụ: assert len(df) > 0)
    except Exception as e:
        print("Error executing query:", e)

# test_11(conn) # Uncomment dòng này để chạy test sau khi viết xong query

# %%
# 12. AVG salary theo department
# Mô tả: Tính trung bình salary của từng department_id.

def get_result_12(conn):
    # TODO: Viết câu query của bạn vào đây
    query = """
    SELECT 1; -- Thay bằng query của bạn
    """
    return pd.read_sql_query(query, conn)

def test_12(conn):
    try:
        df = get_result_12(conn)
        print("Query executed successfully. Result shape:", df.shape)
        display(df.head()) # Hiển thị 5 dòng đầu
        # Nếu muốn test chặt chẽ, có thể thêm các câu lệnh assert ở đây (ví dụ: assert len(df) > 0)
    except Exception as e:
        print("Error executing query:", e)

# test_12(conn) # Uncomment dòng này để chạy test sau khi viết xong query

# %%
# 13. MAX/MIN order amount
# Mô tả: Tìm giá trị order lớn nhất và nhỏ nhất.

def get_result_13(conn):
    # TODO: Viết câu query của bạn vào đây
    query = """
    SELECT 1; -- Thay bằng query của bạn
    """
    return pd.read_sql_query(query, conn)

def test_13(conn):
    try:
        df = get_result_13(conn)
        print("Query executed successfully. Result shape:", df.shape)
        display(df.head()) # Hiển thị 5 dòng đầu
        # Nếu muốn test chặt chẽ, có thể thêm các câu lệnh assert ở đây (ví dụ: assert len(df) > 0)
    except Exception as e:
        print("Error executing query:", e)

# test_13(conn) # Uncomment dòng này để chạy test sau khi viết xong query

# %%
# 14. SUM revenue theo tháng
# Mô tả: Tính tổng revenue (amount) theo từng tháng từ bảng orders.

def get_result_14(conn):
    # TODO: Viết câu query của bạn vào đây
    query = """
    SELECT 1; -- Thay bằng query của bạn
    """
    return pd.read_sql_query(query, conn)

def test_14(conn):
    try:
        df = get_result_14(conn)
        print("Query executed successfully. Result shape:", df.shape)
        display(df.head()) # Hiển thị 5 dòng đầu
        # Nếu muốn test chặt chẽ, có thể thêm các câu lệnh assert ở đây (ví dụ: assert len(df) > 0)
    except Exception as e:
        print("Error executing query:", e)

# test_14(conn) # Uncomment dòng này để chạy test sau khi viết xong query

# %%
# 15. GROUP BY country
# Mô tả: Đếm số lượng user ở mỗi quốc gia.

def get_result_15(conn):
    # TODO: Viết câu query của bạn vào đây
    query = """
    SELECT 1; -- Thay bằng query của bạn
    """
    return pd.read_sql_query(query, conn)

def test_15(conn):
    try:
        df = get_result_15(conn)
        print("Query executed successfully. Result shape:", df.shape)
        display(df.head()) # Hiển thị 5 dòng đầu
        # Nếu muốn test chặt chẽ, có thể thêm các câu lệnh assert ở đây (ví dụ: assert len(df) > 0)
    except Exception as e:
        print("Error executing query:", e)

# test_15(conn) # Uncomment dòng này để chạy test sau khi viết xong query

# %%
# 16. HAVING count > 5
# Mô tả: Không có đủ dữ liệu để count > 5, hãy tìm country có số lượng user > 1.

def get_result_16(conn):
    # TODO: Viết câu query của bạn vào đây
    query = """
    SELECT 1; -- Thay bằng query của bạn
    """
    return pd.read_sql_query(query, conn)

def test_16(conn):
    try:
        df = get_result_16(conn)
        print("Query executed successfully. Result shape:", df.shape)
        display(df.head()) # Hiển thị 5 dòng đầu
        # Nếu muốn test chặt chẽ, có thể thêm các câu lệnh assert ở đây (ví dụ: assert len(df) > 0)
    except Exception as e:
        print("Error executing query:", e)

# test_16(conn) # Uncomment dòng này để chạy test sau khi viết xong query

# %%
# 17. Count duplicate email
# Mô tả: Tìm các name xuất hiện nhiều hơn 1 lần (dùng duplicate name do email unique trong mock).

def get_result_17(conn):
    # TODO: Viết câu query của bạn vào đây
    query = """
    SELECT 1; -- Thay bằng query của bạn
    """
    return pd.read_sql_query(query, conn)

def test_17(conn):
    try:
        df = get_result_17(conn)
        print("Query executed successfully. Result shape:", df.shape)
        display(df.head()) # Hiển thị 5 dòng đầu
        # Nếu muốn test chặt chẽ, có thể thêm các câu lệnh assert ở đây (ví dụ: assert len(df) > 0)
    except Exception as e:
        print("Error executing query:", e)

# test_17(conn) # Uncomment dòng này để chạy test sau khi viết xong query

# %%
# 18. Tìm department có lương trung bình cao nhất
# Mô tả: Sử dụng GROUP BY, ORDER BY và LIMIT.

def get_result_18(conn):
    # TODO: Viết câu query của bạn vào đây
    query = """
    SELECT 1; -- Thay bằng query của bạn
    """
    return pd.read_sql_query(query, conn)

def test_18(conn):
    try:
        df = get_result_18(conn)
        print("Query executed successfully. Result shape:", df.shape)
        display(df.head()) # Hiển thị 5 dòng đầu
        # Nếu muốn test chặt chẽ, có thể thêm các câu lệnh assert ở đây (ví dụ: assert len(df) > 0)
    except Exception as e:
        print("Error executing query:", e)

# test_18(conn) # Uncomment dòng này để chạy test sau khi viết xong query

# %%
# 19. Revenue theo year/month
# Mô tả: Tính tổng revenue theo năm và tháng.

def get_result_19(conn):
    # TODO: Viết câu query của bạn vào đây
    query = """
    SELECT 1; -- Thay bằng query của bạn
    """
    return pd.read_sql_query(query, conn)

def test_19(conn):
    try:
        df = get_result_19(conn)
        print("Query executed successfully. Result shape:", df.shape)
        display(df.head()) # Hiển thị 5 dòng đầu
        # Nếu muốn test chặt chẽ, có thể thêm các câu lệnh assert ở đây (ví dụ: assert len(df) > 0)
    except Exception as e:
        print("Error executing query:", e)

# test_19(conn) # Uncomment dòng này để chạy test sau khi viết xong query

# %%
# 20. Percentage calculation
# Mô tả: Tính phần trăm salary của mỗi user so với tổng salary của toàn bộ user.

def get_result_20(conn):
    # TODO: Viết câu query của bạn vào đây
    query = """
    SELECT 1; -- Thay bằng query của bạn
    """
    return pd.read_sql_query(query, conn)

def test_20(conn):
    try:
        df = get_result_20(conn)
        print("Query executed successfully. Result shape:", df.shape)
        display(df.head()) # Hiển thị 5 dòng đầu
        # Nếu muốn test chặt chẽ, có thể thêm các câu lệnh assert ở đây (ví dụ: assert len(df) > 0)
    except Exception as e:
        print("Error executing query:", e)

# test_20(conn) # Uncomment dòng này để chạy test sau khi viết xong query

# %%
# 21. INNER JOIN users-orders
# Mô tả: Join bảng users và orders để lấy name và amount.

def get_result_21(conn):
    # TODO: Viết câu query của bạn vào đây
    query = """
    SELECT 1; -- Thay bằng query của bạn
    """
    return pd.read_sql_query(query, conn)

def test_21(conn):
    try:
        df = get_result_21(conn)
        print("Query executed successfully. Result shape:", df.shape)
        display(df.head()) # Hiển thị 5 dòng đầu
        # Nếu muốn test chặt chẽ, có thể thêm các câu lệnh assert ở đây (ví dụ: assert len(df) > 0)
    except Exception as e:
        print("Error executing query:", e)

# test_21(conn) # Uncomment dòng này để chạy test sau khi viết xong query

# %%
# 22. LEFT JOIN lấy user chưa order
# Mô tả: Tìm các user chưa từng mua hàng (order_id IS NULL).

def get_result_22(conn):
    # TODO: Viết câu query của bạn vào đây
    query = """
    SELECT 1; -- Thay bằng query của bạn
    """
    return pd.read_sql_query(query, conn)

def test_22(conn):
    try:
        df = get_result_22(conn)
        print("Query executed successfully. Result shape:", df.shape)
        display(df.head()) # Hiển thị 5 dòng đầu
        # Nếu muốn test chặt chẽ, có thể thêm các câu lệnh assert ở đây (ví dụ: assert len(df) > 0)
    except Exception as e:
        print("Error executing query:", e)

# test_22(conn) # Uncomment dòng này để chạy test sau khi viết xong query

# %%
# 23. RIGHT JOIN
# Mô tả: SQLite không hỗ trợ RIGHT JOIN trực tiếp, hãy dùng LEFT JOIN ngược lại hoặc đảo bảng.

def get_result_23(conn):
    # TODO: Viết câu query của bạn vào đây
    query = """
    SELECT 1; -- Thay bằng query của bạn
    """
    return pd.read_sql_query(query, conn)

def test_23(conn):
    try:
        df = get_result_23(conn)
        print("Query executed successfully. Result shape:", df.shape)
        display(df.head()) # Hiển thị 5 dòng đầu
        # Nếu muốn test chặt chẽ, có thể thêm các câu lệnh assert ở đây (ví dụ: assert len(df) > 0)
    except Exception as e:
        print("Error executing query:", e)

# test_23(conn) # Uncomment dòng này để chạy test sau khi viết xong query

# %%
# 24. FULL OUTER JOIN
# Mô tả: Mô phỏng FULL OUTER JOIN (hoặc dùng LEFT JOIN UNION LEFT JOIN).

def get_result_24(conn):
    # TODO: Viết câu query của bạn vào đây
    query = """
    SELECT 1; -- Thay bằng query của bạn
    """
    return pd.read_sql_query(query, conn)

def test_24(conn):
    try:
        df = get_result_24(conn)
        print("Query executed successfully. Result shape:", df.shape)
        display(df.head()) # Hiển thị 5 dòng đầu
        # Nếu muốn test chặt chẽ, có thể thêm các câu lệnh assert ở đây (ví dụ: assert len(df) > 0)
    except Exception as e:
        print("Error executing query:", e)

# test_24(conn) # Uncomment dòng này để chạy test sau khi viết xong query

# %%
# 25. SELF JOIN employee-manager
# Mô tả: Lấy danh sách name của employee và name của manager tương ứng.

def get_result_25(conn):
    # TODO: Viết câu query của bạn vào đây
    query = """
    SELECT 1; -- Thay bằng query của bạn
    """
    return pd.read_sql_query(query, conn)

def test_25(conn):
    try:
        df = get_result_25(conn)
        print("Query executed successfully. Result shape:", df.shape)
        display(df.head()) # Hiển thị 5 dòng đầu
        # Nếu muốn test chặt chẽ, có thể thêm các câu lệnh assert ở đây (ví dụ: assert len(df) > 0)
    except Exception as e:
        print("Error executing query:", e)

# test_25(conn) # Uncomment dòng này để chạy test sau khi viết xong query

# %%
# 26. Multi-table JOIN
# Mô tả: Join users, orders và departments để lấy name, amount và department_name.

def get_result_26(conn):
    # TODO: Viết câu query của bạn vào đây
    query = """
    SELECT 1; -- Thay bằng query của bạn
    """
    return pd.read_sql_query(query, conn)

def test_26(conn):
    try:
        df = get_result_26(conn)
        print("Query executed successfully. Result shape:", df.shape)
        display(df.head()) # Hiển thị 5 dòng đầu
        # Nếu muốn test chặt chẽ, có thể thêm các câu lệnh assert ở đây (ví dụ: assert len(df) > 0)
    except Exception as e:
        print("Error executing query:", e)

# test_26(conn) # Uncomment dòng này để chạy test sau khi viết xong query

# %%
# 27. JOIN + GROUP BY
# Mô tả: Tính tổng order amount của từng department_name.

def get_result_27(conn):
    # TODO: Viết câu query của bạn vào đây
    query = """
    SELECT 1; -- Thay bằng query của bạn
    """
    return pd.read_sql_query(query, conn)

def test_27(conn):
    try:
        df = get_result_27(conn)
        print("Query executed successfully. Result shape:", df.shape)
        display(df.head()) # Hiển thị 5 dòng đầu
        # Nếu muốn test chặt chẽ, có thể thêm các câu lệnh assert ở đây (ví dụ: assert len(df) > 0)
    except Exception as e:
        print("Error executing query:", e)

# test_27(conn) # Uncomment dòng này để chạy test sau khi viết xong query

# %%
# 28. JOIN + aggregate revenue
# Mô tả: Tìm user_name có tổng order amount cao nhất.

def get_result_28(conn):
    # TODO: Viết câu query của bạn vào đây
    query = """
    SELECT 1; -- Thay bằng query của bạn
    """
    return pd.read_sql_query(query, conn)

def test_28(conn):
    try:
        df = get_result_28(conn)
        print("Query executed successfully. Result shape:", df.shape)
        display(df.head()) # Hiển thị 5 dòng đầu
        # Nếu muốn test chặt chẽ, có thể thêm các câu lệnh assert ở đây (ví dụ: assert len(df) > 0)
    except Exception as e:
        print("Error executing query:", e)

# test_28(conn) # Uncomment dòng này để chạy test sau khi viết xong query

# %%
# 29. Duplicate rows after join
# Mô tả: Quan sát hiện tượng duplicate khi 1 user có nhiều order. Query lấy user name và count số order.

def get_result_29(conn):
    # TODO: Viết câu query của bạn vào đây
    query = """
    SELECT 1; -- Thay bằng query của bạn
    """
    return pd.read_sql_query(query, conn)

def test_29(conn):
    try:
        df = get_result_29(conn)
        print("Query executed successfully. Result shape:", df.shape)
        display(df.head()) # Hiển thị 5 dòng đầu
        # Nếu muốn test chặt chẽ, có thể thêm các câu lệnh assert ở đây (ví dụ: assert len(df) > 0)
    except Exception as e:
        print("Error executing query:", e)

# test_29(conn) # Uncomment dòng này để chạy test sau khi viết xong query

# %%
# 30. Anti Join (NOT EXISTS)
# Mô tả: Dùng NOT EXISTS để tìm user chưa từng order.

def get_result_30(conn):
    # TODO: Viết câu query của bạn vào đây
    query = """
    SELECT 1; -- Thay bằng query của bạn
    """
    return pd.read_sql_query(query, conn)

def test_30(conn):
    try:
        df = get_result_30(conn)
        print("Query executed successfully. Result shape:", df.shape)
        display(df.head()) # Hiển thị 5 dòng đầu
        # Nếu muốn test chặt chẽ, có thể thêm các câu lệnh assert ở đây (ví dụ: assert len(df) > 0)
    except Exception as e:
        print("Error executing query:", e)

# test_30(conn) # Uncomment dòng này để chạy test sau khi viết xong query

# %%
# 31. User có salary > average salary
# Mô tả: Dùng subquery trong mệnh đề WHERE.

def get_result_31(conn):
    # TODO: Viết câu query của bạn vào đây
    query = """
    SELECT 1; -- Thay bằng query của bạn
    """
    return pd.read_sql_query(query, conn)

def test_31(conn):
    try:
        df = get_result_31(conn)
        print("Query executed successfully. Result shape:", df.shape)
        display(df.head()) # Hiển thị 5 dòng đầu
        # Nếu muốn test chặt chẽ, có thể thêm các câu lệnh assert ở đây (ví dụ: assert len(df) > 0)
    except Exception as e:
        print("Error executing query:", e)

# test_31(conn) # Uncomment dòng này để chạy test sau khi viết xong query

# %%
# 32. Correlated subquery
# Mô tả: Tìm user có salary lớn hơn average salary của chính department của họ.

def get_result_32(conn):
    # TODO: Viết câu query của bạn vào đây
    query = """
    SELECT 1; -- Thay bằng query của bạn
    """
    return pd.read_sql_query(query, conn)

def test_32(conn):
    try:
        df = get_result_32(conn)
        print("Query executed successfully. Result shape:", df.shape)
        display(df.head()) # Hiển thị 5 dòng đầu
        # Nếu muốn test chặt chẽ, có thể thêm các câu lệnh assert ở đây (ví dụ: assert len(df) > 0)
    except Exception as e:
        print("Error executing query:", e)

# test_32(conn) # Uncomment dòng này để chạy test sau khi viết xong query

# %%
# 33. EXISTS vs IN
# Mô tả: Dùng IN để tìm các user đã từng order.

def get_result_33(conn):
    # TODO: Viết câu query của bạn vào đây
    query = """
    SELECT 1; -- Thay bằng query của bạn
    """
    return pd.read_sql_query(query, conn)

def test_33(conn):
    try:
        df = get_result_33(conn)
        print("Query executed successfully. Result shape:", df.shape)
        display(df.head()) # Hiển thị 5 dòng đầu
        # Nếu muốn test chặt chẽ, có thể thêm các câu lệnh assert ở đây (ví dụ: assert len(df) > 0)
    except Exception as e:
        print("Error executing query:", e)

# test_33(conn) # Uncomment dòng này để chạy test sau khi viết xong query

# %%
# 34. NOT EXISTS
# Mô tả: Tương tự bài 30, dùng NOT EXISTS.

def get_result_34(conn):
    # TODO: Viết câu query của bạn vào đây
    query = """
    SELECT 1; -- Thay bằng query của bạn
    """
    return pd.read_sql_query(query, conn)

def test_34(conn):
    try:
        df = get_result_34(conn)
        print("Query executed successfully. Result shape:", df.shape)
        display(df.head()) # Hiển thị 5 dòng đầu
        # Nếu muốn test chặt chẽ, có thể thêm các câu lệnh assert ở đây (ví dụ: assert len(df) > 0)
    except Exception as e:
        print("Error executing query:", e)

# test_34(conn) # Uncomment dòng này để chạy test sau khi viết xong query

# %%
# 35. Highest salary per department
# Mô tả: Tìm user có salary cao nhất trong mỗi department (dùng subquery).

def get_result_35(conn):
    # TODO: Viết câu query của bạn vào đây
    query = """
    SELECT 1; -- Thay bằng query của bạn
    """
    return pd.read_sql_query(query, conn)

def test_35(conn):
    try:
        df = get_result_35(conn)
        print("Query executed successfully. Result shape:", df.shape)
        display(df.head()) # Hiển thị 5 dòng đầu
        # Nếu muốn test chặt chẽ, có thể thêm các câu lệnh assert ở đây (ví dụ: assert len(df) > 0)
    except Exception as e:
        print("Error executing query:", e)

# test_35(conn) # Uncomment dòng này để chạy test sau khi viết xong query

# %%
# 36. Second highest salary
# Mô tả: Tìm mức salary cao thứ 2 trong công ty.

def get_result_36(conn):
    # TODO: Viết câu query của bạn vào đây
    query = """
    SELECT 1; -- Thay bằng query của bạn
    """
    return pd.read_sql_query(query, conn)

def test_36(conn):
    try:
        df = get_result_36(conn)
        print("Query executed successfully. Result shape:", df.shape)
        display(df.head()) # Hiển thị 5 dòng đầu
        # Nếu muốn test chặt chẽ, có thể thêm các câu lệnh assert ở đây (ví dụ: assert len(df) > 0)
    except Exception as e:
        print("Error executing query:", e)

# test_36(conn) # Uncomment dòng này để chạy test sau khi viết xong query

# %%
# 37. Top N salary
# Mô tả: Tìm top 3 salary cao nhất (dùng LIMIT hoặc Subquery).

def get_result_37(conn):
    # TODO: Viết câu query của bạn vào đây
    query = """
    SELECT 1; -- Thay bằng query của bạn
    """
    return pd.read_sql_query(query, conn)

def test_37(conn):
    try:
        df = get_result_37(conn)
        print("Query executed successfully. Result shape:", df.shape)
        display(df.head()) # Hiển thị 5 dòng đầu
        # Nếu muốn test chặt chẽ, có thể thêm các câu lệnh assert ở đây (ví dụ: assert len(df) > 0)
    except Exception as e:
        print("Error executing query:", e)

# test_37(conn) # Uncomment dòng này để chạy test sau khi viết xong query

# %%
# 38. Nested subquery
# Mô tả: Tìm user nằm trong department có tổng salary > 10000.

def get_result_38(conn):
    # TODO: Viết câu query của bạn vào đây
    query = """
    SELECT 1; -- Thay bằng query của bạn
    """
    return pd.read_sql_query(query, conn)

def test_38(conn):
    try:
        df = get_result_38(conn)
        print("Query executed successfully. Result shape:", df.shape)
        display(df.head()) # Hiển thị 5 dòng đầu
        # Nếu muốn test chặt chẽ, có thể thêm các câu lệnh assert ở đây (ví dụ: assert len(df) > 0)
    except Exception as e:
        print("Error executing query:", e)

# test_38(conn) # Uncomment dòng này để chạy test sau khi viết xong query

# %%
# 39. Scalar subquery
# Mô tả: Lấy danh sách user kèm theo 1 cột là average salary của toàn công ty.

def get_result_39(conn):
    # TODO: Viết câu query của bạn vào đây
    query = """
    SELECT 1; -- Thay bằng query của bạn
    """
    return pd.read_sql_query(query, conn)

def test_39(conn):
    try:
        df = get_result_39(conn)
        print("Query executed successfully. Result shape:", df.shape)
        display(df.head()) # Hiển thị 5 dòng đầu
        # Nếu muốn test chặt chẽ, có thể thêm các câu lệnh assert ở đây (ví dụ: assert len(df) > 0)
    except Exception as e:
        print("Error executing query:", e)

# test_39(conn) # Uncomment dòng này để chạy test sau khi viết xong query

# %%
# 40. Derived table
# Mô tả: Dùng subquery ở mệnh đề FROM.

def get_result_40(conn):
    # TODO: Viết câu query của bạn vào đây
    query = """
    SELECT 1; -- Thay bằng query của bạn
    """
    return pd.read_sql_query(query, conn)

def test_40(conn):
    try:
        df = get_result_40(conn)
        print("Query executed successfully. Result shape:", df.shape)
        display(df.head()) # Hiển thị 5 dòng đầu
        # Nếu muốn test chặt chẽ, có thể thêm các câu lệnh assert ở đây (ví dụ: assert len(df) > 0)
    except Exception as e:
        print("Error executing query:", e)

# test_40(conn) # Uncomment dòng này để chạy test sau khi viết xong query

# %%
# 41. ROW_NUMBER() ranking
# Mô tả: Xếp hạng user theo salary giảm dần dùng ROW_NUMBER().

def get_result_41(conn):
    # TODO: Viết câu query của bạn vào đây
    query = """
    SELECT 1; -- Thay bằng query của bạn
    """
    return pd.read_sql_query(query, conn)

def test_41(conn):
    try:
        df = get_result_41(conn)
        print("Query executed successfully. Result shape:", df.shape)
        display(df.head()) # Hiển thị 5 dòng đầu
        # Nếu muốn test chặt chẽ, có thể thêm các câu lệnh assert ở đây (ví dụ: assert len(df) > 0)
    except Exception as e:
        print("Error executing query:", e)

# test_41(conn) # Uncomment dòng này để chạy test sau khi viết xong query

# %%
# 42. RANK vs DENSE_RANK
# Mô tả: So sánh RANK() và DENSE_RANK() qua việc xếp hạng salary.

def get_result_42(conn):
    # TODO: Viết câu query của bạn vào đây
    query = """
    SELECT 1; -- Thay bằng query của bạn
    """
    return pd.read_sql_query(query, conn)

def test_42(conn):
    try:
        df = get_result_42(conn)
        print("Query executed successfully. Result shape:", df.shape)
        display(df.head()) # Hiển thị 5 dòng đầu
        # Nếu muốn test chặt chẽ, có thể thêm các câu lệnh assert ở đây (ví dụ: assert len(df) > 0)
    except Exception as e:
        print("Error executing query:", e)

# test_42(conn) # Uncomment dòng này để chạy test sau khi viết xong query

# %%
# 43. Running total
# Mô tả: Tính tổng lũy kế (running total) của order amount theo ngày.

def get_result_43(conn):
    # TODO: Viết câu query của bạn vào đây
    query = """
    SELECT 1; -- Thay bằng query của bạn
    """
    return pd.read_sql_query(query, conn)

def test_43(conn):
    try:
        df = get_result_43(conn)
        print("Query executed successfully. Result shape:", df.shape)
        display(df.head()) # Hiển thị 5 dòng đầu
        # Nếu muốn test chặt chẽ, có thể thêm các câu lệnh assert ở đây (ví dụ: assert len(df) > 0)
    except Exception as e:
        print("Error executing query:", e)

# test_43(conn) # Uncomment dòng này để chạy test sau khi viết xong query

# %%
# 44. Moving average
# Mô tả: Tính trung bình trượt 2 dòng của order amount.

def get_result_44(conn):
    # TODO: Viết câu query của bạn vào đây
    query = """
    SELECT 1; -- Thay bằng query của bạn
    """
    return pd.read_sql_query(query, conn)

def test_44(conn):
    try:
        df = get_result_44(conn)
        print("Query executed successfully. Result shape:", df.shape)
        display(df.head()) # Hiển thị 5 dòng đầu
        # Nếu muốn test chặt chẽ, có thể thêm các câu lệnh assert ở đây (ví dụ: assert len(df) > 0)
    except Exception as e:
        print("Error executing query:", e)

# test_44(conn) # Uncomment dòng này để chạy test sau khi viết xong query

# %%
# 45. LEAD/LAG previous-next order
# Mô tả: Lấy amount của order hiện tại và order liền trước nó của cùng một user.

def get_result_45(conn):
    # TODO: Viết câu query của bạn vào đây
    query = """
    SELECT 1; -- Thay bằng query của bạn
    """
    return pd.read_sql_query(query, conn)

def test_45(conn):
    try:
        df = get_result_45(conn)
        print("Query executed successfully. Result shape:", df.shape)
        display(df.head()) # Hiển thị 5 dòng đầu
        # Nếu muốn test chặt chẽ, có thể thêm các câu lệnh assert ở đây (ví dụ: assert len(df) > 0)
    except Exception as e:
        print("Error executing query:", e)

# test_45(conn) # Uncomment dòng này để chạy test sau khi viết xong query

# %%
# 46. First order per customer
# Mô tả: Tìm order đầu tiên của mỗi user.

def get_result_46(conn):
    # TODO: Viết câu query của bạn vào đây
    query = """
    SELECT 1; -- Thay bằng query của bạn
    """
    return pd.read_sql_query(query, conn)

def test_46(conn):
    try:
        df = get_result_46(conn)
        print("Query executed successfully. Result shape:", df.shape)
        display(df.head()) # Hiển thị 5 dòng đầu
        # Nếu muốn test chặt chẽ, có thể thêm các câu lệnh assert ở đây (ví dụ: assert len(df) > 0)
    except Exception as e:
        print("Error executing query:", e)

# test_46(conn) # Uncomment dòng này để chạy test sau khi viết xong query

# %%
# 47. Latest login per user
# Mô tả: Tìm order gần nhất (latest order) của mỗi user.

def get_result_47(conn):
    # TODO: Viết câu query của bạn vào đây
    query = """
    SELECT 1; -- Thay bằng query của bạn
    """
    return pd.read_sql_query(query, conn)

def test_47(conn):
    try:
        df = get_result_47(conn)
        print("Query executed successfully. Result shape:", df.shape)
        display(df.head()) # Hiển thị 5 dòng đầu
        # Nếu muốn test chặt chẽ, có thể thêm các câu lệnh assert ở đây (ví dụ: assert len(df) > 0)
    except Exception as e:
        print("Error executing query:", e)

# test_47(conn) # Uncomment dòng này để chạy test sau khi viết xong query

# %%
# 48. Partition by department
# Mô tả: Sử dụng Window Function để tính AVG salary theo department ngay trên dòng của user.

def get_result_48(conn):
    # TODO: Viết câu query của bạn vào đây
    query = """
    SELECT 1; -- Thay bằng query của bạn
    """
    return pd.read_sql_query(query, conn)

def test_48(conn):
    try:
        df = get_result_48(conn)
        print("Query executed successfully. Result shape:", df.shape)
        display(df.head()) # Hiển thị 5 dòng đầu
        # Nếu muốn test chặt chẽ, có thể thêm các câu lệnh assert ở đây (ví dụ: assert len(df) > 0)
    except Exception as e:
        print("Error executing query:", e)

# test_48(conn) # Uncomment dòng này để chạy test sau khi viết xong query

# %%
# 49. Top 3 salary each department
# Mô tả: Lấy danh sách top 3 người lương cao nhất mỗi department.

def get_result_49(conn):
    # TODO: Viết câu query của bạn vào đây
    query = """
    SELECT 1; -- Thay bằng query của bạn
    """
    return pd.read_sql_query(query, conn)

def test_49(conn):
    try:
        df = get_result_49(conn)
        print("Query executed successfully. Result shape:", df.shape)
        display(df.head()) # Hiển thị 5 dòng đầu
        # Nếu muốn test chặt chẽ, có thể thêm các câu lệnh assert ở đây (ví dụ: assert len(df) > 0)
    except Exception as e:
        print("Error executing query:", e)

# test_49(conn) # Uncomment dòng này để chạy test sau khi viết xong query

# %%
# 50. Detect duplicate consecutive records
# Mô tả: Dùng LAG để tìm các user có cùng mức lương (giả định sắp xếp theo salary).

def get_result_50(conn):
    # TODO: Viết câu query của bạn vào đây
    query = """
    SELECT 1; -- Thay bằng query của bạn
    """
    return pd.read_sql_query(query, conn)

def test_50(conn):
    try:
        df = get_result_50(conn)
        print("Query executed successfully. Result shape:", df.shape)
        display(df.head()) # Hiển thị 5 dòng đầu
        # Nếu muốn test chặt chẽ, có thể thêm các câu lệnh assert ở đây (ví dụ: assert len(df) > 0)
    except Exception as e:
        print("Error executing query:", e)

# test_50(conn) # Uncomment dòng này để chạy test sau khi viết xong query
